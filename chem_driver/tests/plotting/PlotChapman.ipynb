# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
data = np.genfromtxt("Chapman.dat", dtype=str)
Header = (data[0,:]).tolist()
solTchem = (data[1:,:]).astype(float)

# %%
print(Header)
# Out:
# ['iter', 't', 'dt', 'Density[kg/m3]', 'Pressure[Pascal]', 'Temperature[K]', 'Ar', 'CO2', 'H2O', 'N2', 'O1D', 'O', 'O2', 'O3', 'M']

# %%
for var in Header:
    var_indx=Header.index(var)
    plt.figure()
    plt.plot(solTchem[:,1]/3600,solTchem[:,var_indx] )
    plt.xlabel('Time [hr]')
    plt.ylabel(var)

# %%
import pandas as pd
df = pd.read_csv('chapman_const_photo.csv')
for col in df:
    plt.figure()
    plt.plot(df.time/3600,df[col])
    plt.xlabel('Time [hr]')
    plt.ylabel(col)
